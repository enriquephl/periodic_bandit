# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
z=[]
for i in range(1,1000):
    z.append({"x": i, "y": 100*np.sqrt(i), "y_bar": 100*np.sqrt(i)/i})
df=pd.DataFrame(z)
sns.lineplot(x="x",y="y",data=df)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
sns.lineplot(x="x",y="y_bar",data=df)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y_bar'>
